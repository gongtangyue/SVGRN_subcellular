# %%
import pandas as pd

# %%
expr_path = "E:\st\SVGRN_subcellular\in_sim\g110_c2k_n01\expression_loc_cluster_wlayout.csv"
expr_df = pd.read_csv(expr_path, index_col=0)

# %%
expr_df
# Out:
#                  1         2         3         4         5         6  \
# cell1     3.339016  5.382383  5.026818  5.132764  6.171271  2.493406
# cell2     2.617323  5.333352  5.177466  5.038690  6.090427  2.390330
# cell3     3.088700  5.491983  4.491137  5.220172  6.570258  2.403840
# cell4     3.153994  5.378722  4.744001  5.122851  6.471762  2.413590
# cell5     2.967068  5.371222  5.397548  5.085691  6.446140  2.423390
# ...            ...       ...       ...       ...       ...       ...
# cell1996  2.626014  5.585827  4.811957  5.273721  6.336723  2.328042
# cell1997  2.243782  5.423198  4.944250  5.091372  6.271004  2.746752
# cell1998  2.037162  5.524304  4.855270  5.113518  6.313732  2.451867
# cell1999  2.186395  5.507605  4.745182  5.431663  6.531753  2.374579
# cell2000  2.094936  5.506139  4.457308  5.509014  6.469476  2.481729
#
#                  7         8         9        10  ...       104       105  \
# ...
